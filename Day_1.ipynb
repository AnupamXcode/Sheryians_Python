# %%
print("A">"B")
a=ord("A")
print(a)
print(type(a))
#int isliye coz ascai values hai
# Out:
# False
# 65
# <class 'int'>

# %%
print("ABC">"ACD")

#phele A check hoga fir B aur C compare honge (ASCII) tab final hoga
# Out:
# False

# %%
age = int(input("Enter age: "))

if age < 13:
    print("Child")
elif age <= 19:
    print("Teenager")
elif age <= 59:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Enter age: 20
# Adult

# %%
print("ABC">"ABC")
# Out:
# False
